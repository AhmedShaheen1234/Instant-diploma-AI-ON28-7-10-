# %%
import requests
from bs4 import BeautifulSoup
#some import lib
url_of_website = 'https://books.toscrape.com/catalogue/page-{}.html'
#this will keep the url of website in variable url_of_website
page = 1 #count for number of page
while True:
    url = url_of_website.format(page)
    response = requests.get(url)
    if response.status_code != 200:
        break
    #sends an HTTP GET request to the URL 
    content = response.content
    #her the content
    soup = BeautifulSoup(content, 'html.parser')
    books = soup.find_all('article', class_='product_pod')
    for book in books:
        title = book.h3.a['title']
        #extracts the title of book
        price = book.select('div p.price_color')[0].text
        rating = 'No rating' if 'star-rating' not in str(book) else book.select('p.star-rating')[0]['class'][1]
        #if there is no rating for a book
        print(f"The title of book = {title}")
        print(f"The price of book =  {price}")
        print(f"The rating for book out of 5 = {rating}")
        print("----------")
        # print informations
    page = page + 1
# Out:
# The title of book = A Light in the Attic
# The price of book =  £51.77
# The rating for book out of 5 = Three
# ----------
# The title of book = Tipping the Velvet
# The price of book =  £53.74
# The rating for book out of 5 = One
# ----------
# The title of book = Soumission
# The price of book =  £50.10
# The rating for book out of 5 = One
# ----------
# The title of book = Sharp Objects
# The price of book =  £47.82
# The rating for book out of 5 = Four
# ----------
# The title of book = Sapiens: A Brief History of Humankind
# The price of book =  £54.23
# The rating for book out of 5 = Five
# ----------
# The title of book = The Requiem Red
# The price of book =  £22.65
# The rating for book out of 5 = One
# ----------
# The title of book = The Dirty Little Secrets of Getting Your Dream Job
# The price of book =  £33.34
# The rating for book out of 5 = Four
# ----------
# The title of book = The Coming Woman: A Novel Based on the Life of the Infamous Feminist, Victoria Woodhull
# The price of book =  £17.93
# The rating for book out of 5 = Three
# ----------
# The title of book = The Boys in the Boat: Nine Americans and Their Epic Quest for Gold at the 1936 Berlin Olympics
# The price of book =  £22.60
# The rating for book out of 5 = Four
# ----------
# The title of book = The Black Maria
# The price of book =  £52.15
# The rating for book out of 5 = One
# ----------
# The title of book = Starving Hearts (Triangular Trade Trilogy, #1)
# The price of book =  £13.99
# The rating for book out of 5 = Two
# ----------
# The title of book = Shakespeare's Sonnets
# The price of book =  £20.66
# The rating for book out of 5 = Four
# ----------
# The title of book = Set Me Free
# The price of book =  £17.46
# The rating for book out of 5 = Five
# ----------
# The title of book = Scott Pilgrim's Precious Little Life (Scott Pilgrim #1)
# The price of book =  £52.29
# The rating for book out of 5 = Five
# ----------
# The title of book = Rip it Up and Start Again
# The price of book =  £35.02
# The rating for book out of 5 = Five
# ----------
# The title of book = Our Band Could Be Your Life: Scenes from the American Indie Underground, 1981-1991
# The price of book =  £57.25
# The rating for book out of 5 = Three
# ----------
# The title of book = Olio
# The price of book =  £23.88
# The rating for book out of 5 = One
# ----------
# The title of book = Mesaerion: The Best Science Fiction Stories 1800-1849
# The price of book =  £37.59
# The rating for book out of 5 = One
# ----------
# The title of book = Libertarianism for Beginners
# The price of book =  £51.33
# The rating for book out of 5 = Two
# ----------
# The title of book = It's Only the Himalayas
# The price of book =  £45.17
# The rating for book out of 5 = Two
# ----------
# The title of book = In Her Wake
# The price of book =  £12.84
# The rating for book out of 5 = One
# ----------
# The title of book = How Music Works
# The price of book =  £37.32
# The rating for book out of 5 = Two
# ----------
# The title of book = Foolproof Preserving: A Guide to Small Batch Jams, Jellies, Pickles, Condiments, and More: A Foolproof Guide to Making Small Batch Jams, Jellies, Pickles, Condiments, and More
# The price of book =  £30.52
# The rating for book out of 5 = Three
# ----------
# The title of book = Chase Me (Paris Nights #2)
# The price of book =  £25.27
# The rating for book out of 5 = Five
# ----------
# The title of book = Black Dust
# The price of book =  £34.53
# The rating for book out of 5 = Five
# ----------
# The title of book = Birdsong: A Story in Pictures
# The price of book =  £54.64
# The rating for book out of 5 = Three
# ----------
# The title of book = America's Cradle of Quarterbacks: Western Pennsylvania's Football Factory from Johnny Unitas to Joe Montana
# The price of book =  £22.50
# The rating for book out of 5 = Three
# ----------
# The title of book = Aladdin and His Wonderful Lamp
# The price of book =  £53.13
# The rating for book out of 5 = Three
# ----------
# The title of book = Worlds Elsewhere: Journeys Around Shakespeare’s Globe
# The price of book =  £40.30
# The rating for book out of 5 = Five
# ----------
# The title of book = Wall and Piece
# The price of book =  £44.18
# The rating for book out of 5 = Four
# ----------
# The title of book = The Four Agreements: A Practical Guide to Personal Freedom
# The price of book =  £17.66
# The rating for book out of 5 = Five
# ----------
# The title of book = The Five Love Languages: How to Express Heartfelt Commitment to Your Mate
# The price of book =  £31.05
# The rating for book out of 5 = Three
# ----------
# The title of book = The Elephant Tree
# The price of book =  £23.82
# The rating for book out of 5 = Five
# ----------
# The title of book = The Bear and the Piano
# The price of book =  £36.89
# The rating for book out of 5 = One
# ----------
# The title of book = Sophie's World
# The price of book =  £15.94
# The rating for book out of 5 = Five
# ----------
# The title of book = Penny Maybe
# The price of book =  £33.29
# The rating for book out of 5 = Three
# ----------
# The title of book = Maude (1883-1993):She Grew Up with the country
# The price of book =  £18.02
# The rating for book out of 5 = Two
# ----------
# The title of book = In a Dark, Dark Wood
# The price of book =  £19.63
# The rating for book out of 5 = One
# ----------
# The title of book = Behind Closed Doors
# The price of book =  £52.22
# The rating for book out of 5 = Four
# ----------
# The title of book = You can't bury them all: Poems
# The price of book =  £33.63
# The rating for book out of 5 = Two
# ----------
# The title of book = Slow States of Collapse: Poems
# The price of book =  £57.31
# The rating for book out of 5 = Three
# ----------
# The title of book = Reasons to Stay Alive
# The price of book =  £26.41
# The rating for book out of 5 = Two
# ----------
# The title of book = Private Paris (Private #10)
# The price of book =  £47.61
# The rating for book out of 5 = Five
# ----------
# The title of book = #HigherSelfie: Wake Up Your Life. Free Your Soul. Find Your Tribe.
# The price of book =  £23.11
# The rating for book out of 5 = Five
# ----------
# The title of book = Without Borders (Wanderlove #1)
# The price of book =  £45.07
# The rating for book out of 5 = Two
# ----------
# The title of book = When We Collided
# The price of book =  £31.77
# The rating for book out of 5 = One
# ----------
# The title of book = We Love You, Charlie Freeman
# The price of book =  £50.27
# The rating for book out of 5 = Five
# ----------
# The title of book = Untitled Collection: Sabbath Poems 2014
# The price of book =  £14.27
# The rating for book out of 5 = Four
# ----------
# The title of book = Unseen City: The Majesty of Pigeons, the Discreet Charm of Snails & Other Wonders of the Urban Wilderness
# The price of book =  £44.18
# The rating for book out of 5 = Four
# ----------
# The title of book = Unicorn Tracks
# The price of book =  £18.78
# The rating for book out of 5 = Three
# ----------
# The title of book = Unbound: How Eight Technologies Made Us Human, Transformed Society, and Brought Our World to the Brink
# The price of book =  £25.52
# The rating for book out of 5 = One
# ----------
# The title of book = Tsubasa: WoRLD CHRoNiCLE 2 (Tsubasa WoRLD CHRoNiCLE #2)
# The price of book =  £16.28
# The rating for book out of 5 = One
# ----------
# The title of book = Throwing Rocks at the Google Bus: How Growth Became the Enemy of Prosperity
# The price of book =  £31.12
# The rating for book out of 5 = Three
# ----------
# The title of book = This One Summer
# The price of book =  £19.49
# The rating for book out of 5 = Four
# ----------
# The title of book = Thirst
# The price of book =  £17.27
# The rating for book out of 5 = Five
# ----------
# The title of book = The Torch Is Passed: A Harding Family Story
# The price of book =  £19.09
# The rating for book out of 5 = One
# ----------
# The title of book = The Secret of Dreadwillow Carse
# The price of book =  £56.13
# The rating for book out of 5 = One
# ----------
# The title of book = The Pioneer Woman Cooks: Dinnertime: Comfort Classics, Freezer Food, 16-Minute Meals, and Other Delicious Ways to Solve Supper!
# The price of book =  £56.41
# The rating for book out of 5 = One
# ----------
# The title of book = The Past Never Ends
# The price of book =  £56.50
# The rating for book out of 5 = Four
# ----------
# The title of book = The Natural History of Us (The Fine Art of Pretending #2)
# The price of book =  £45.22
# The rating for book out of 5 = Three
# ----------
# The title of book = The Nameless City (The Nameless City #1)
# The price of book =  £38.16
# The rating for book out of 5 = Four
# ----------
# The title of book = The Murder That Never Was (Forensic Instincts #5)
# The price of book =  £54.11
# The rating for book out of 5 = Three
# ----------
# The title of book = The Most Perfect Thing: Inside (and Outside) a Bird's Egg
# The price of book =  £42.96
# The rating for book out of 5 = Four
# ----------
# The title of book = The Mindfulness and Acceptance Workbook for Anxiety: A Guide to Breaking Free from Anxiety, Phobias, and Worry Using Acceptance and Commitment Therapy
# The price of book =  £23.89
# The rating for book out of 5 = Four
# ----------
# The title of book = The Life-Changing Magic of Tidying Up: The Japanese Art of Decluttering and Organizing
# The price of book =  £16.77
# The rating for book out of 5 = Three
# ----------
# The title of book = The Inefficiency Assassin: Time Management Tactics for Working Smarter, Not Longer
# The price of book =  £20.59
# The rating for book out of 5 = Five
# ----------
# The title of book = The Gutsy Girl: Escapades for Your Life of Epic Adventure
# The price of book =  £37.13
# The rating for book out of 5 = One
# ----------
# The title of book = The Electric Pencil: Drawings from Inside State Hospital No. 3
# The price of book =  £56.06
# The rating for book out of 5 = One
# ----------
# The title of book = The Death of Humanity: and the Case for Life
# The price of book =  £58.11
# The rating for book out of 5 = Four
# ----------
# The title of book = The Bulletproof Diet: Lose up to a Pound a Day, Reclaim Energy and Focus, Upgrade Your Life
# The price of book =  £49.05
# The rating for book out of 5 = Three
# ----------
# The title of book = The Art Forger
# The price of book =  £40.76
# The rating for book out of 5 = Three
# ----------
# The title of book = The Age of Genius: The Seventeenth Century and the Birth of the Modern Mind
# The price of book =  £19.73
# The rating for book out of 5 = One
# ----------
# The title of book = The Activist's Tao Te Ching: Ancient Advice for a Modern Revolution
# The price of book =  £32.24
# The rating for book out of 5 = Five
# ----------
# The title of book = Spark Joy: An Illustrated Master Class on the Art of Organizing and Tidying Up
# The price of book =  £41.83
# The rating for book out of 5 = Four
# ----------
# The title of book = Soul Reader
# The price of book =  £39.58
# The rating for book out of 5 = Two
# ----------
# The title of book = Security
# The price of book =  £39.25
# The rating for book out of 5 = Two
# ----------
# The title of book = Saga, Volume 6 (Saga (Collected Editions) #6)
# The price of book =  £25.02
# The rating for book out of 5 = Three
# ----------
# The title of book = Saga, Volume 5 (Saga (Collected Editions) #5)
# The price of book =  £51.04
# The rating for book out of 5 = Two
# ----------
# The title of book = Reskilling America: Learning to Labor in the Twenty-First Century
# The price of book =  £19.83
# The rating for book out of 5 = Two
# ----------
# The title of book = Rat Queens, Vol. 3: Demons (Rat Queens (Collected Editions) #11-15)
# The price of book =  £50.40
# The rating for book out of 5 = Three
# ----------
# The title of book = Princess Jellyfish 2-in-1 Omnibus, Vol. 01 (Princess Jellyfish 2-in-1 Omnibus #1)
# The price of book =  £13.61
# The rating for book out of 5 = Five
# ----------
# The title of book = Princess Between Worlds (Wide-Awake Princess #5)
# The price of book =  £13.34
# The rating for book out of 5 = Five
# ----------
# The title of book = Pop Gun War, Volume 1: Gift
# The price of book =  £18.97
# The rating for book out of 5 = One
# ----------
# The title of book = Political Suicide: Missteps, Peccadilloes, Bad Calls, Backroom Hijinx, Sordid Pasts, Rotten Breaks, and Just Plain Dumb Mistakes in the Annals of American Politics
# The price of book =  £36.28
# The rating for book out of 5 = Two
# ----------
# The title of book = Patience
# The price of book =  £10.16
# The rating for book out of 5 = Three
# ----------
# The title of book = Outcast, Vol. 1: A Darkness Surrounds Him (Outcast #1)
# The price of book =  £15.44
# The rating for book out of 5 = Four
# ----------
# The title of book = orange: The Complete Collection 1 (orange: The Complete Collection #1)
# The price of book =  £48.41
# The rating for book out of 5 = One
# ----------
# The title of book = Online Marketing for Busy Authors: A Step-By-Step Guide
# The price of book =  £46.35
# The rating for book out of 5 = One
# ----------
# The title of book = On a Midnight Clear
# The price of book =  £14.07
# The rating for book out of 5 = Three
# ----------
# The title of book = Obsidian (Lux #1)
# The price of book =  £14.86
# The rating for book out of 5 = Two
# ----------
# The title of book = My Paris Kitchen: Recipes and Stories
# The price of book =  £33.37
# The rating for book out of 5 = Two
# ----------
# The title of book = Masks and Shadows
# The price of book =  £56.40
# The rating for book out of 5 = Two
# ----------
# The title of book = Mama Tried: Traditional Italian Cooking for the Screwed, Crude, Vegan, and Tattooed
# The price of book =  £14.02
# The rating for book out of 5 = Four
# ----------
# The title of book = Lumberjanes, Vol. 2: Friendship to the Max (Lumberjanes #5-8)
# The price of book =  £46.91
# The rating for book out of 5 = Two
# ----------
# The title of book = Lumberjanes, Vol. 1: Beware the Kitten Holy (Lumberjanes #1-4)
# The price of book =  £45.61
# The rating for book out of 5 = Three
# ----------
# The title of book = Lumberjanes Vol. 3: A Terrible Plan (Lumberjanes #9-12)
# The price of book =  £19.92
# The rating for book out of 5 = Two
# ----------
# The title of book = Layered: Baking, Building, and Styling Spectacular Cakes
# The price of book =  £40.11
# The rating for book out of 5 = One
# ----------
# The title of book = Judo: Seven Steps to Black Belt (an Introductory Guide for Beginners)
# The price of book =  £53.90
# The rating for book out of 5 = Two
# ----------
# The title of book = Join
# The price of book =  £35.67
# The rating for book out of 5 = Five
# ----------
# The title of book = In the Country We Love: My Family Divided
# The price of book =  £22.00
# The rating for book out of 5 = Four
# ----------
# The title of book = Immunity: How Elie Metchnikoff Changed the Course of Modern Medicine
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 20
#      18 price = book.select('div p.price_color')[0].text
#      19 rating = 'No rating' if 'star-rating' not in str(book) else book.select('p.star-rating')[0]['class'][1]
# ---> 20 print(f"The title of book = {title}")
#      21 print(f"The price of book =  {price}")
#      22 print(f"The rating for book out of 5 = {rating}")
#
# File ~\anaconda3\Lib\site-packages\ipykernel\iostream.py:563, in OutStream.write(self, string)
#     561         self.pub_thread.schedule(self._flush)
#     562     else:
# --> 563         self._schedule_flush()
#     565 return len(string)
#
# File ~\anaconda3\Lib\site-packages\ipykernel\iostream.py:469, in OutStream._schedule_flush(self)
#     466 def _schedule_in_thread():
#     467     self._io_loop.call_later(self.flush_interval, self._flush)
# --> 469 self.pub_thread.schedule(_schedule_in_thread)
#
# File ~\anaconda3\Lib\site-packages\ipykernel\iostream.py:210, in IOPubThread.schedule(self, f)
#     208     self._events.append(f)
#     209     # wake event thread (message content is ignored)
# --> 210     self._event_pipe.send(b"")
#     211 else:
#     212     f()
#
# File ~\anaconda3\Lib\site-packages\zmq\sugar\socket.py:696, in Socket.send(self, data, flags, copy, track, routing_id, group)
#     689         data = zmq.Frame(
#     690             data,
#     691             track=track,
#     692             copy=copy or None,
#     693             copy_threshold=self.copy_threshold,
#     694         )
#     695     data.group = group
# --> 696 return super().send(data, flags=flags, copy=copy, track=track)
#
# File zmq/backend/cython/socket.pyx:742, in zmq.backend.cython.socket.Socket.send()
#
# File zmq/backend/cython/socket.pyx:789, in zmq.backend.cython.socket.Socket.send()
#
# File zmq/backend/cython/socket.pyx:250, in zmq.backend.cython.socket._send_copy()
#
# File ~\anaconda3\Lib\site-packages\zmq\backend\cython\checkrc.pxd:13, in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
